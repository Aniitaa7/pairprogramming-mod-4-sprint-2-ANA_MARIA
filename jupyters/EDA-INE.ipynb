# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
#!pip install xlrd

# %%
df1 = pd.read_csv('../Datasets/INE/Brecha de género en las tasas de empleo según edad en la UE y periodo.csv', sep=';')

# %%
df1.head(15)
# Out:
#        Países   Grupos de edad  Periodo Total
# 0   UE27_2020  De 15 a 64 años     2023   9,3
# 1   UE27_2020  De 15 a 64 años     2022   9,8
# 2   UE27_2020  De 15 a 64 años     2021    10
# 3   UE27_2020  De 15 a 64 años     2020  10,1
# 4   UE27_2020  De 15 a 64 años     2019  10,3
# 5   UE27_2020  De 15 a 64 años     2018  10,3
# 6   UE27_2020  De 15 a 64 años     2017  10,3
# 7   UE27_2020  De 15 a 64 años     2016  10,2
# 8   UE27_2020  De 15 a 64 años     2015  10,2
# 9   UE27_2020  De 15 a 64 años     2014  10,1
# 10  UE27_2020  De 15 a 64 años     2013  10,3
# 11  UE27_2020  De 15 a 24 años     2023   4,2
# 12  UE27_2020  De 15 a 24 años     2022   4,7
# 13  UE27_2020  De 15 a 24 años     2021   4,7
# 14  UE27_2020  De 15 a 24 años     2020   4,8

# %%
df1.tail()
# Out:
#            Países   Grupos de edad  Periodo Total
# 1645  Reino Unido  De 55 a 64 años     2017  10,1
# 1646  Reino Unido  De 55 a 64 años     2016  12,1
# 1647  Reino Unido  De 55 a 64 años     2015  12,6
# 1648  Reino Unido  De 55 a 64 años     2014  13,4
# 1649  Reino Unido  De 55 a 64 años     2013  13,8

# %%
df1['Países'].unique()
# Out:
# array(['UE27_2020', 'UE-28', 'Bélgica', 'Bulgaria', 'República Checa',
#        'Dinamarca', 'Alemania', 'Estonia', 'Irlanda', 'Grecia', 'España',
#        'Francia', 'Croacia', 'Italia', 'Chipre', 'Letonia', 'Lituania',
#        'Luxemburgo', 'Hungría', 'Malta', 'Países Bajos', 'Austria',
#        'Polonia', 'Portugal', 'Rumanía', 'Eslovenia',
#        'República Eslovaca', 'Finlandia', 'Suecia', 'Reino Unido'],
#       dtype=object)

# %%
df1.shape
# Out:
# (1650, 4)

# %%
df2 = pd.read_csv('../Datasets/INE/Brecha de género en las tasas de empleo según grupos de edad y periodo. España, UE-27 y UE-28.csv', sep=';')

# %%
df2.tail(20)
# Out:
#     España y UE   Grupos de edad  Periodo Total
# 115   UE27_2020  De 20 a 64 años     2013  11,3
# 116   UE27_2020  De 20 a 64 años     2012  11,8
# 117   UE27_2020  De 20 a 64 años     2011  12,5
# 118   UE27_2020  De 20 a 64 años     2010  12,7
# 119   UE27_2020  De 20 a 64 años     2009  13,4
# 120   UE27_2020  De 55 a 64 años     2023    12
# 121   UE27_2020  De 55 a 64 años     2022  12,5
# 122   UE27_2020  De 55 a 64 años     2021  12,6
# 123   UE27_2020  De 55 a 64 años     2020  12,5
# 124   UE27_2020  De 55 a 64 años     2019  13,1
# 125   UE27_2020  De 55 a 64 años     2018  13,1
# 126   UE27_2020  De 55 a 64 años     2017  12,8
# 127   UE27_2020  De 55 a 64 años     2016  12,8
# 128   UE27_2020  De 55 a 64 años     2015    13
# 129   UE27_2020  De 55 a 64 años     2014  13,2
# 130   UE27_2020  De 55 a 64 años     2013  13,7
# 131   UE27_2020  De 55 a 64 años     2012  14,2
# 132   UE27_2020  De 55 a 64 años     2011  14,6
# 133   UE27_2020  De 55 a 64 años     2010  15,8
# ...

# %%
df3 = pd.read_csv('../Datasets/INE/Brecha de género en las tasas de empleo según periodo. España, UE-27 y UE-28 (de 15 a 64 años).csv', sep=';')
df3.head()
# Out:
#   España y UE  Periodo Total
# 0       UE-28     2023    ..
# 1       UE-28     2022    ..
# 2       UE-28     2021    ..
# 3       UE-28     2020    ..
# 4       UE-28     2019  10,4

# %%
df4 = pd.read_csv('../Datasets/INE/Brecha salarial de género -no ajustada a las características individuales- en salario por hora, sector público, sector privado.csv', sep=';')
df4
# Out:
#           Países         Sector profesional  Periodo Total
# 0          UE-28  Asalariado sector público     2021   NaN
# 1          UE-28  Asalariado sector público     2020   NaN
# 2          UE-28  Asalariado sector público     2019   NaN
# 3          UE-28  Asalariado sector público     2018   NaN
# 4          UE-28  Asalariado sector público     2017   NaN
# ..           ...                        ...      ...   ...
# 749  Reino Unido  Asalariado sector privado     2013  24,7
# 750  Reino Unido  Asalariado sector privado     2012  27,1
# 751  Reino Unido  Asalariado sector privado     2011  26,4
# 752  Reino Unido  Asalariado sector privado     2010    23
# 753  Reino Unido  Asalariado sector privado     2009  26,1
#
# [754 rows x 4 columns]

# %%
df5 = pd.read_csv('../Datasets/INE/Brecha salarial de género (no ajustada a las características individuales) en salario por hora por edad y periodo..csv', sep=';')
df5
# Out:
#       Grupos de edad  Periodo Total
# 0   Menos de 25 años     2021  -3,8
# 1   Menos de 25 años     2020  -3,8
# 2   Menos de 25 años     2019    -3
# 3   Menos de 25 años     2018   1,7
# 4   Menos de 25 años     2017   4,1
# ..               ...      ...   ...
# 73     65 y más años     2013  43,5
# 74     65 y más años     2012  48,9
# 75     65 y más años     2011  51,9
# 76     65 y más años     2010  45,1
# 77     65 y más años     2009    ..
#
# [78 rows x 3 columns]

# %%
df6 = pd.read_csv('../Datasets/INE/Brecha salarial de género (no ajustada a las características individuales) en salario por hora por tipo de jornada y periodo. España.csv', sep=';')
df6.head()
# Out:
#              Tipo de jornada Total Nacional  Periodo Total
# 0  Jornada a tiempo completo         España     2021   2,5
# 1  Jornada a tiempo completo         España     2020   2,5
# 2  Jornada a tiempo completo         España     2019   3,4
# 3  Jornada a tiempo completo         España     2018   6,5
# 4  Jornada a tiempo completo         España     2017     8

# %%
df6.shape
# Out:
# (26, 4)

# %%
df7 = pd.read_excel('../Datasets/INE/Mujeres empleadas en ciencia y tecnología (reparto por sectores). España y UE-27. Serie 2020-2022 (%).xls')
df7
# Out:
#    Mujeres empleadas en ciencia y tecnología (reparto por sectores). España y UE-27. Serie 2020-2022 (%)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                               Todos
# 4   Sectores de alta tecnología (manufacturas y se...
# 5                                        Manufacturas
# 6           Alta y media-alta tecnología manufacturas
# 7                                           Servicios
# 8                Servicios intensivos en conocimiento
# 9                                                 NaN
# 10  Notas: Incluye mujeres de 25 a 64 años. Incluy...
# 11                      UE-27: 27 países (desde 2020)
# 12                               (b) Ruptura de serie
# 13  Fuente: Recursos Humanos en Ciencia y Tecnolog...
# 14  http://ec.europa.eu/eurostat/data/database?nod...
#
# ...

# %%
df8 = pd.read_csv('../Datasets/INE/Tasa de empleo según niveles de educación en la UE (de 20 a 64 años) y periodo.csv', sep=';')
df8.head()
# Out:
#       Países Sexo/Brecha de género  \
# 0  UE27_2020               Mujeres
# 1  UE27_2020               Mujeres
# 2  UE27_2020               Mujeres
# 3  UE27_2020               Mujeres
# 4  UE27_2020               Mujeres
#
#                                 Niveles de educación  Periodo Total
# 0  Preescolar, primaria y secundaria 1ª etapa (ni...     2023  46,8
# 1  Preescolar, primaria y secundaria 1ª etapa (ni...     2022  45,6
# 2  Preescolar, primaria y secundaria 1ª etapa (ni...     2021  43,5
# 3  Preescolar, primaria y secundaria 1ª etapa (ni...     2020  43,4
# 4  Preescolar, primaria y secundaria 1ª etapa (ni...     2019  44,4

# %%
df8.tail()
# Out:
#            Países                 Sexo/Brecha de género  \
# 2965  Reino Unido  Brecha de género (hombres - mujeres)
# 2966  Reino Unido  Brecha de género (hombres - mujeres)
# 2967  Reino Unido  Brecha de género (hombres - mujeres)
# 2968  Reino Unido  Brecha de género (hombres - mujeres)
# 2969  Reino Unido  Brecha de género (hombres - mujeres)
#
#                 Niveles de educación  Periodo Total
# 2965  Educación superior (nivel 5-8)     2017   7,4
# 2966  Educación superior (nivel 5-8)     2016   7,4
# 2967  Educación superior (nivel 5-8)     2015     7
# 2968  Educación superior (nivel 5-8)     2014     7
# 2969  Educación superior (nivel 5-8)     2013     7

# %%
df8['Países'].unique()
# Out:
# array(['UE27_2020', 'UE-28', 'Bélgica', 'Bulgaria', 'República Checa',
#        'Dinamarca', 'Alemania', 'Estonia', 'Irlanda', 'Grecia', 'España',
#        'Francia', 'Croacia', 'Italia', 'Chipre', 'Letonia', 'Lituania',
#        'Luxemburgo', 'Hungría', 'Malta', 'Países Bajos', 'Austria',
#        'Polonia', 'Portugal', 'Rumanía', 'Eslovenia',
#        'República Eslovaca', 'Finlandia', 'Suecia', 'Reino Unido'],
#       dtype=object)

# %%
df8.shape
# Out:
# (2970, 5)

# %%
df9 = pd.read_csv('../Datasets/INE/Tasa de paro según niveles de educación en la UE (de 15 a 74 años).csv', sep=';')
df9.head()
# Out:
#       Países                               Niveles de educación     Sexo  \
# 0  UE27_2020  Preescolar, primaria y secundaria 1ª etapa (ni...  Mujeres
# 1  UE27_2020  Preescolar, primaria y secundaria 1ª etapa (ni...  Mujeres
# 2  UE27_2020  Preescolar, primaria y secundaria 1ª etapa (ni...  Mujeres
# 3  UE27_2020  Preescolar, primaria y secundaria 1ª etapa (ni...  Mujeres
# 4  UE27_2020  Preescolar, primaria y secundaria 1ª etapa (ni...  Mujeres
#
#    Periodo Total
# 0     2023  13,4
# 1     2022  13,9
# 2     2021  15,4
# 3     2020  14,9
# 4     2019  14,5

# %%
df9.shape
# Out:
# (2700, 5)

# %%
df9['Países'].unique()
# Out:
# array(['UE27_2020', 'UE-28', 'Bélgica', 'Bulgaria', 'República Checa',
#        'Dinamarca', 'Alemania', 'Estonia', 'Irlanda', 'Grecia', 'España',
#        'Francia', 'Croacia', 'Italia', 'Chipre', 'Letonia', 'Lituania',
#        'Luxemburgo', 'Hungría', 'Malta', 'Países Bajos', 'Austria',
#        'Polonia', 'Portugal', 'Rumanía', 'Eslovenia',
#        'República Eslovaca', 'Finlandia', 'Suecia', 'Reino Unido'],
#       dtype=object)

# %%
df10 = pd.read_csv('../Datasets/INE/Tasa de paro según niveles de educación y grupos de edad en la UE.csv', sep=';')
df10.head()
# Out:
#       Sexo     Países                               Niveles de educación  \
# 0  Mujeres  UE27_2020  Preescolar, primaria y secundaria 1ª etapa (ni...
# 1  Mujeres  UE27_2020  Preescolar, primaria y secundaria 1ª etapa (ni...
# 2  Mujeres  UE27_2020  Preescolar, primaria y secundaria 1ª etapa (ni...
# 3  Mujeres  UE27_2020  Preescolar, primaria y secundaria 1ª etapa (ni...
# 4  Mujeres  UE27_2020  Preescolar, primaria y secundaria 1ª etapa (ni...
#
#     Grupos de edad  Periodo Total
# 0  De 15 a 24 años     2023  19,4
# 1  De 15 a 24 años     2022  20,1
# 2  De 15 a 24 años     2021  24,1
# 3  De 15 a 24 años     2020  23,3
# 4  De 15 a 24 años     2019  21,3

# %%
df10.shape
# Out:
# (10800, 6)

# %%
df10['Grupos de edad'].unique()
# Out:
# array(['De 15 a 24 años', 'De 25 a 49 años', 'De 50 a 59 años',
#        'De 60 a 64 años'], dtype=object)

# %%
df10['Niveles de educación'].unique()
# Out:
# array(['Preescolar, primaria y secundaria 1ª etapa (nivel 0-2)',
#        'Secundaria 2ª etapa (nivel 3-4)',
#        'Educación superior (nivel 5-8)'], dtype=object)

# %%
df11 = pd.read_csv('../Datasets/INE/Tasa de paro y brecha de género (De 15 a 74 años) según periodo en la UE.csv', sep=';')
df11.head()
# Out:
#       Países Sexo/Brecha de género  Periodo Total
# 0  UE27_2020               Mujeres     2023   6,3
# 1  UE27_2020               Mujeres     2022   6,5
# 2  UE27_2020               Mujeres     2021   7,4
# 3  UE27_2020               Mujeres     2020   7,6
# 4  UE27_2020               Mujeres     2019   7,2

# %%
df11.shape
# Out:
# (1350, 4)

# %%
df12 = pd.read_csv('../Datasets/INE/Porcentaje de hombres y mujeres graduados en educación superior en la UE. CNED-2014.csv', sep=';')
df12.head()
# Out:
#   Países     Sexo  Periodo Total
# 0  UE-28  Hombres     2020    ..
# 1  UE-28  Hombres     2019  45,9
# 2  UE-28  Hombres     2018  45,9
# 3  UE-28  Hombres     2017    46
# 4  UE-28  Hombres     2016    46

# %%
df12['Países'].unique()
# Out:
# array(['UE-28', 'UE27_2020', 'Bélgica', 'Bulgaria', 'República Checa',
#        'Dinamarca', 'Alemania', 'Estonia', 'Irlanda', 'Grecia', 'España',
#        'Francia', 'Croacia', 'Italia', 'Chipre', 'Letonia', 'Lituania',
#        'Luxemburgo', 'Hungría', 'Malta', 'Países Bajos', 'Austria',
#        'Polonia', 'Portugal', 'Rumanía', 'Eslovenia',
#        'República Eslovaca', 'Finlandia', 'Suecia', 'Reino Unido'],
#       dtype=object)

# %%
df12['Periodo'].unique()
# Out:
# array([2020, 2019, 2018, 2017, 2016, 2015, 2014], dtype=int64)

# %%
df12.shape
# Out:
# (420, 4)

# %%
df13 = pd.read_csv('../Datasets/INE/Mujeres graduadas en educación superior por campo de estudio. España y UE-28. CNED-2014.csv', sep=';')
df13.head()
# Out:
#   Campo de estudio  Países  Periodo Total
# 0     01 Educación  España     2020   8,8
# 1     01 Educación  España     2019   8,6
# 2     01 Educación  España     2018     9
# 3     01 Educación  España     2017   8,9
# 4     01 Educación  España     2016     9

# %%
df13['Campo de estudio'].unique()
# Out:
# array(['01 Educación', '02 Artes, humanidades y lenguas',
#        '03 Ciencias sociales, periodismo y documentación',
#        '04 Negocios, administración y derecho',
#        'Ciencias naturales, matemáticas y estadística',
#        '06 Tecnologías de la información y las comunicaciones (TIC)',
#        '0732 Construcción e ingeniería civil',
#        '08 Agricultura, ganadería, pesca, silvicultura y veterinaria',
#        '09 Salud y servicios sociales', '10 Servicios'], dtype=object)

# %%
df14 = pd.read_csv('../Datasets/INE/Mujeres en el profesorado de educación universitaria en las universidades públicas por categoría y curso.csv', sep=';')
df14.head()
# Out:
#              Categoría profesional  Periodo Total
# 0  Cuerpos docentes universitarios     2019  36,8
# 1  Cuerpos docentes universitarios     2018  36,3
# 2  Cuerpos docentes universitarios     2017  35,9
# 3  Cuerpos docentes universitarios     2016  35,7
# 4  Cuerpos docentes universitarios     2015  35,5

# %%
df14['Categoría profesional'].unique()
# Out:
# array(['Cuerpos docentes universitarios', 'Catedráticos de universidad',
#        'Titulares de universidad',
#        'Catedráticos de escuela universitaria',
#        'Titulares de escuela universitaria', 'Otros',
#        'Personal contratado', 'Personal emérito'], dtype=object)

# %%
df14['Periodo'].unique()
# Out:
# array([2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011], dtype=int64)
